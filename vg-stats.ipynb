# %% [markdown]
# # vg-stats

# %%
import pandas as pd

# %%
df = pd.read_csv('./vgsales.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# 1. Which company is the most common video game publisher?

# %%
df['Publisher'].mode()
# Out:
# 0    Electronic Arts
# dtype: object

# %% [markdown]
# 2. What’s the most common platform?

# %%
df['Platform'].mode()
# Out:
# 0    DS
# dtype: object

# %% [markdown]
# 3. What about the most common genre?

# %%
df['Genre'].mode()
# Out:
# 0    Action
# dtype: object

# %% [markdown]
# 4. What are the top 20 highest grossing games?

# %%
df.sort_values('Global_Sales', ascending=False)[['Name']].head(20)
# Out:
#                                             Name
# 0                                     Wii Sports
# 1                              Super Mario Bros.
# 2                                 Mario Kart Wii
# 3                              Wii Sports Resort
# 4                       Pokemon Red/Pokemon Blue
# 5                                         Tetris
# 6                          New Super Mario Bros.
# 7                                       Wii Play
# 8                      New Super Mario Bros. Wii
# 9                                      Duck Hunt
# 10                                    Nintendogs
# 11                                 Mario Kart DS
# 12                   Pokemon Gold/Pokemon Silver
# 13                                       Wii Fit
# 14                                  Wii Fit Plus
# 15                            Kinect Adventures!
# 16                            Grand Theft Auto V
# 17                 Grand Theft Auto: San Andreas
# 18                             Super Mario World
# 19  Brain Age: Train Your Brain in Minutes a Day

# %% [markdown]
# 5. For North American video game sales, what’s the median?

# %%
df['NA_Sales'].median()
# Out:
# 0.08

# %% [markdown]
# * Provide a secondary output showing ten games surrounding the median sales output
# * assume that games with same median value are sorted in descending order

# %%
sorting_decading = df.sort_values('NA_Sales', ascending=False)
remove_deplicating = sorting_decading.drop_duplicates(subset=['NA_Sales'])
 
under_median = remove_deplicating[remove_deplicating['NA_Sales'] > 0.08 ][['Name']].tail(5)

above_median = remove_deplicating[remove_deplicating['NA_Sales'] < 0.08 ][['Name']].head(5)
 

above_median,under_median
# Out:
# (                                                Name
#  11438                         Diego's Build & Rescue
#  10009                                     Smash Cars
#  12482                    Disney Sports Skateboarding
#  10972  Total Overdose: A Gunslinger's Tale in Mexico
#  13510                           Trollz: Hair Affair!,
#                                           Name
#  5145  Theatrhythm Final Fantasy: Curtain Call
#  5071              Need for Speed: Hot Pursuit
#  9155                               Bio FREAKS
#  7550                  Saturday Night Speedway
#  7928                        Rise of the Kasai)

# %% [markdown]
# 6. For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
top_selling_game = df.sort_values('Global_Sales', ascending=False)[['NA_Sales']].head(1)
top_selling_game
# Out:
#    NA_Sales
# 0     41.49

# %%
(top_selling_game - df['NA_Sales'].mean())/ df['NA_Sales'].std()
# Out:
#     NA_Sales
# 0  50.478988

# %% [markdown]
# 7. The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms? Come up with 3 more questions that can be answered with this data set.

# %%
wii_average_sales =  df[df['Platform'] == 'Wii']['Global_Sales'].mean()
wii_average_sales
# Out:
# 0.6994037735849057

# %%
average_other_platforms = df[df['Platform'] != 'Wii']['Global_Sales'].mean()

# %%
average_other_platforms
# Out:
# 0.5233896418516336

# %%
wii_average_sales /average_other_platforms   # it 13% bigger than other games
# Out:
# 1.3362965516676526
